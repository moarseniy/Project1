# %% [markdown]
# Zdarova guys, eto ssanyi prototip version 0.10

# %%
import pandas as pd
import numpy as np
import os
import pickle

# %%
os.chdir('/home/moarseniy/git_workspace/Project1/')

# %% [markdown]
# OpenStreetMap (https://habrahabr.ru/post/270513/) или, например, NextGIS (http://nextgis.ru/services/dataosm/).

# %%
import geopandas as gpd
# %matplotlib inline
mo_gdf = gpd.read_file('atd/mo.shp')
#mo_gdf.head()

# %%
mo_gdf.plot()

# %% [markdown]
# Podrobnee tut https://habrahabr.ru/post/235283/

# %%
mo_gdf_wm = mo_gdf.to_crs({'init' :'epsg:3857'}) 
mo_gdf_wm.plot(column = 'ABBREV_AO', linewidth=0.5, cmap='plasma', legend=True, figsize=[15,15])

# %%
mo_gdf_wm.plot(column = 'TYPE_MO', linewidth=0.5, cmap='plasma', legend=True, figsize=[15,15])
